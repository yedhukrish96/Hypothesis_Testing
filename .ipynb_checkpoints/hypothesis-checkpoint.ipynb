# %% [markdown]
# # Before you start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas

import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1 - Exploring the Data
#
# In this challenge, we will examine all salaries of employees of the City of Chicago. We will start by loading the dataset and examining its contents.

# %%
# Your code here:
data = pd.read_csv('Current_Employee_Names__Salaries__and_Position_Titles.csv')

# %% [markdown]
# Examine the `salaries` dataset using the `head` function below.

# %%
# Your code here:

data.head(10)
# Out:
#                       Name                               Job Titles  \
# 0   ADRIANO,  RACQUEL ANNE                                PARAMEDIC
# 1        AFFANEH,  MAHIR A                           POLICE OFFICER
# 2        AFOENYI,  PHYLLIS                TITLE V PROGRAM TRAINEE I
# 3          AGAR,  BULENT B                      DEPUTY COMMISSIONER
# 4          AGEE,  LAWRENCE                           POLICE OFFICER
# 5        AGNEW,  ANTONIO E                       MOTOR TRUCK DRIVER
# 6        AGNEW,  MELISSA M                                 SERGEANT
# 7        AGOSTA,  JOSEPH J   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 8  AGOSTINELLI,  MICHAEL A  FIREFIGHTER (PER ARBITRATORS AWARD)-EMT
# 9        AGOSTINI,  LUIS R                                 ASST DIR
#
#          Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 0              FIRE                 F           Salary            NaN
# 1            POLICE                 F           Salary            NaN
# ...

# %% [markdown]
# We see from looking at the `head` function that there is quite a bit of missing data. Let's examine how much missing data is in each column. Produce this output in the cell below

# %%
# Your code here:
data['Typical Hours'].isna().sum()
# Out:
# 25528

# %%
data['Annual Salary'].isna().sum()
# Out:
# 8174

# %%
data['Hourly Rate'].isna().sum()
# Out:
# 25528

# %% [markdown]
# Let's also look at the count of hourly vs. salaried employees. Write the code in the cell below

# %%
# Your code here:
data['Salary or Hourly'].value_counts()
# Out:
# Salary    25528
# Hourly     8174
# Name: Salary or Hourly, dtype: int64

# %% [markdown]
# What this information indicates is that the table contains information about two types of employees - salaried and hourly. Some columns apply only to one type of employee while other columns only apply to another kind. This is why there are so many missing values. Therefore, we will not do anything to handle the missing values.

# %% [markdown]
# There are different departments in the city. List all departments and the count of employees in each department.

# %%
# Your code here:
data['Department'].value_counts()
# Out:
# POLICE                 13848
# FIRE                    4627
# STREETS & SAN           2175
# WATER MGMNT             1914
# AVIATION                1856
# OEMC                    1737
# TRANSPORTN              1113
# PUBLIC LIBRARY          1088
# DAIS                    1033
# FAMILY & SUPPORT         656
# FINANCE                  544
# HEALTH                   467
# LAW                      398
# CITY COUNCIL             362
# BUILDINGS                258
# PUBLIC SAFETY ADMIN      244
# BUSINESS AFFAIRS         167
# HOUSING & ECON DEV       154
# COPA                     123
# BOARD OF ELECTION        111
# MAYOR'S OFFICE           104
# INSPECTOR GEN             95
# CITY CLERK                88
# PROCUREMENT               84
# HUMAN RESOURCES           75
# ANIMAL CONTRL             75
# CULTURAL AFFAIRS          74
# HOUSING                   66
# BUDGET & MGMT             44
# ADMIN HEARNG              38
# DISABILITIES              28
# TREASURER                 28
# ...

# %% [markdown]
# # Challenge 2 - Hypothesis Tests
#
# In this section of the lab, we will test whether the hourly wage of all hourly workers is significantly different from $30/hr. Import the correct one sample test function from scipy and perform the hypothesis test for a 95% two sided confidence interval.

# %%
# Your code here:
import sys
np.set_printoptions(threshold=sys.maxsize)

s_sample = data['Hourly Rate'].to_numpy()
s_sample = s_sample[~np.isnan(s_sample)]
s_sample
# Out:
# array([ 13.  ,  37.45,  40.78,  38.52,  34.98,  37.45,  25.  ,  38.52,
#         19.86,  49.35,   2.65,  49.35,  29.96,  37.45,  29.96,  49.26,
#         46.88,  49.35,  54.05,  44.82,  38.01,  43.72,  37.45,  18.52,
#         49.6 ,  22.75,  38.52,  43.72,   2.65,  38.52,  34.83,  22.1 ,
#         37.45,  13.  ,  19.86,  38.52,  37.45,  14.1 ,  13.94,  23.38,
#         37.45,  16.65,  23.74,  43.72,  37.45,   2.65,  43.72,  37.45,
#         31.12,  37.45,  37.45,  38.52,  37.45,  38.52,  37.45,  13.  ,
#         38.09,  18.01,  15.55,  19.86,  37.45,  37.45,  37.45,  29.96,
#         51.85,  40.78,  37.45,  19.86,   2.65,  48.93,  37.45,  45.5 ,
#         38.11,  48.93,  13.  ,  43.72,  38.52,  15.94,  38.11,  43.72,
#         43.72,  29.96,  49.26,  54.05,  37.45,  43.72,  20.31,  51.  ,
#         18.52,  38.52,  33.71,  46.25,   2.65,  34.98,  22.36,  19.86,
#         38.52,  51.1 ,  18.52,  18.45,  19.38,  51.85,  14.54,  38.52,
# ...

# %%
import scipy.stats
from scipy.stats import ttest_1samp

stat, pval = ttest_1samp(s_sample,30)

# %%
print('stat is  ', stat)
print('pvalue for the two-tailed test is ', pval)
# Out:
# stat is   31.211500329216044
# pvalue for the two-tailed test is  3.825475847673794e-202

# %%
np.mean(s_sample) - 30
# Out:
# 4.586449718620017

# %%
scipy.stats.sem(s_sample)*stat
# Out:
# 4.586449718620017

# %% [markdown]
# We are also curious about salaries in the police force. The chief of police in Chicago claimed in a press briefing that salaries this year are higher than last year's mean of $86000/year a year for all salaried employees. Test this one sided hypothesis using a 95% confidence interval.
#
# Hint: A one tailed test has a p-value that is half of the two tailed p-value. If our hypothesis is greater than, then to reject, the test statistic must also be positive.

# %%
# Your code here:
police_df = data[data['Department'] == 'POLICE']
p_sample = police_df['Annual Salary'].to_numpy()
p_sample = p_sample[~np.isnan(p_sample)]
p_sample
# Out:
# array([ 93354.,  90024., 111444., 103932.,  95736.,  94524.,  48078.,
#        122472.,  90024.,  84054.,  84054., 111444.,  94122.,  48078.,
#         93354.,  72510.,  84054.,  87006.,  72510., 111444.,  93354.,
#         48078.,  68616.,  84054.,  76266.,  84054.,  80016.,  76266.,
#         93354.,  72510.,  84054.,  72510.,  80016., 100980.,  80016.,
#         90024.,  90024.,  72510.,  94122.,  87006.,  93354.,  80016.,
#         90024.,  48072.,  84054.,  84054.,  87006.,  90024., 100980.,
#         93354.,  90024.,  90024.,  90024.,  48078.,  93354.,  48078.,
#         80016.,  96060.,  58500.,  87006.,  80016.,  93354.,  80016.,
#         84054.,  90024.,  72510.,  90024., 100980., 107208.,  87006.,
#         46428.,  76266.,  76266., 103932.,  96060.,  76266.,  72510.,
#         84054.,  84054.,  84054., 100980.,  93354.,  72510., 114948.,
#         84054.,  90024.,  58500., 111444.,  96060., 122472.,  48078.,
# ...

# %%
import scipy.stats
from scipy.stats import ttest_1samp

stat1, pval1 = ttest_1samp(p_sample,86000)

# %%
print('stat is  ', stat1)
print('pvalue for the two-tailed test is ', pval1)
print('pvalue for the one-tailed test is ', pval1/2)
# Out:
# stat is   18.51748561981861
# pvalue for the two-tailed test is  1.2239133904242963e-75
# pvalue for the one-tailed test is  6.119566952121482e-76

# %% [markdown]
# Using the `crosstab` function, find the department that has the most hourly workers.

# %%
# Your code here:
data_crosstab = pd.crosstab(data['Department'], data['Salary or Hourly'], margins=False)
data_crosstab

#streets and san has the highest hourly workers.
# Out:
# Salary or Hourly     Hourly  Salary
# Department
# ADMIN HEARNG              0      38
# ANIMAL CONTRL            12      63
# AVIATION               1214     642
# BOARD OF ELECTION         0     111
# BOARD OF ETHICS           0       8
# BUDGET & MGMT             2      42
# BUILDINGS                 0     258
# BUSINESS AFFAIRS          7     160
# CITY CLERK                0      88
# CITY COUNCIL             74     288
# COPA                      0     123
# CULTURAL AFFAIRS         10      64
# DAIS                    745     288
# DISABILITIES              1      27
# FAMILY & SUPPORT        357     299
# FINANCE                  45     499
# FIRE                      0    4627
# HEALTH                    2     465
# HOUSING                   0      66
# HOUSING & ECON DEV        3     151
# HUMAN RELATIONS           0      17
# HUMAN RESOURCES           0      75
# INSPECTOR GEN             0      95
# LAW                      48     350
# ...

# %% [markdown]
# The workers from the department with the most hourly workers have complained that their hourly wage is less than $35/hour. Using a one sample t-test, test this one-sided hypothesis at the 95% confidence level.

# %%
# Your code here:
streetssan_df = data[data['Department'] == 'STREETS & SAN']
st_sample = streetssan_df['Hourly Rate'].to_numpy()
st_sample = st_sample[~np.isnan(st_sample)]
st_sample
# Out:
# array([40.78, 38.52, 38.52, 29.96, 37.45, 38.01, 38.52, 38.52, 38.52,
#        37.45, 23.74, 37.45, 37.45, 37.45, 38.52, 37.45, 38.52, 37.45,
#        37.45, 29.96, 40.78, 37.45, 38.52, 37.45, 38.52, 38.52, 38.52,
#        38.52, 37.45, 37.45, 38.52, 38.52, 25.95, 38.52, 37.45, 40.78,
#        29.96, 37.45, 29.96, 38.52, 37.45, 37.45, 38.52, 29.96, 39.64,
#        37.45, 38.01, 37.45, 37.45, 23.74, 29.96, 37.45, 37.45, 38.52,
#        38.52, 37.45, 38.52, 38.52, 37.45, 38.52, 38.52, 37.45, 37.45,
#        37.45, 38.52, 37.45, 47.3 , 38.52, 38.52, 38.52, 23.05, 25.95,
#        37.45, 31.7 , 38.52, 38.52, 25.95, 38.52, 29.96, 23.74, 37.45,
#        29.96, 38.52, 31.7 , 38.52, 39.64, 22.38, 29.96, 33.71, 22.38,
#        24.46, 29.96, 37.45, 38.52, 37.45, 37.45, 37.45, 23.74, 38.52,
#        38.52, 37.45, 37.45, 38.52, 37.45, 21.73, 37.45, 38.52, 38.52,
#        38.52, 38.52, 37.45, 25.19, 38.52, 37.45, 38.52, 38.52, 29.96,
# ...

# %%
import scipy.stats
from scipy.stats import ttest_1samp

stat2, pval2 = ttest_1samp(st_sample,35)

# %%
print('stat is  ', stat2)
print('pvalue for the two-tailed test is ', pval2)
print('pvalue for the one-tailed test is ', pval/2)
# Out:
# stat is   4.000138803968834
# pvalue for the two-tailed test is  6.580474443773579e-05
# pvalue for the one-tailed test is  1.912737923836897e-202

# %% [markdown]
# # Challenge 3: To practice - Constructing Confidence Intervals
#
# While testing our hypothesis is a great way to gather empirical evidence for accepting or rejecting the hypothesis, another way to gather evidence is by creating a confidence interval. A confidence interval gives us information about the true mean of the population. So for a 95% confidence interval, we are 95% sure that the mean of the population is within the confidence interval.
# ).
#
# To read more about confidence intervals, click [here](https://en.wikipedia.org/wiki/Confidence_interval).
#
#
# In the cell below, we will construct a 95% confidence interval for the mean hourly wage of all hourly workers.
#
# The confidence interval is computed in SciPy using the `t.interval` function. You can read more about this function [here](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.t.html).
#
# To compute the confidence interval of the hourly wage, use the 0.95 for the confidence level, number of rows - 1 for degrees of freedom, the mean of the sample for the location parameter and the standard error for the scale. The standard error can be computed using [this](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.sem.html) function in SciPy.

# %%
# Your code here:
hourly_df = data[data["Salary or Hourly"]=='Hourly']
h_sample = hourly_df['Hourly Rate'].to_numpy()
h_sample = h_sample[~np.isnan(h_sample)]
h_sample
# Out:
# array([ 13.  ,  37.45,  40.78,  38.52,  34.98,  37.45,  25.  ,  38.52,
#         19.86,  49.35,   2.65,  49.35,  29.96,  37.45,  29.96,  49.26,
#         46.88,  49.35,  54.05,  44.82,  38.01,  43.72,  37.45,  18.52,
#         49.6 ,  22.75,  38.52,  43.72,   2.65,  38.52,  34.83,  22.1 ,
#         37.45,  13.  ,  19.86,  38.52,  37.45,  14.1 ,  13.94,  23.38,
#         37.45,  16.65,  23.74,  43.72,  37.45,   2.65,  43.72,  37.45,
#         31.12,  37.45,  37.45,  38.52,  37.45,  38.52,  37.45,  13.  ,
#         38.09,  18.01,  15.55,  19.86,  37.45,  37.45,  37.45,  29.96,
#         51.85,  40.78,  37.45,  19.86,   2.65,  48.93,  37.45,  45.5 ,
#         38.11,  48.93,  13.  ,  43.72,  38.52,  15.94,  38.11,  43.72,
#         43.72,  29.96,  49.26,  54.05,  37.45,  43.72,  20.31,  51.  ,
#         18.52,  38.52,  33.71,  46.25,   2.65,  34.98,  22.36,  19.86,
#         38.52,  51.1 ,  18.52,  18.45,  19.38,  51.85,  14.54,  38.52,
# ...

# %%
len(h_sample)
# Out:
# 8174

# %%
sum(h_sample)/8174
# Out:
# 34.58644971862046

# %%
np.std(h_sample)/np.sqrt(8173)
# Out:
# 0.14694742867989574

# %%
import scipy.stats

confidence_level = 0.95
degrees_freedom = len(h_sample) - 1  # or, for large values of sample size, just use that
sample_mean = np.mean(h_sample)

sample_standard_error = scipy.stats.sem(h_sample) # sem = standard error of the mean = std(patients)/sqrt(samplesize)

confidence_interval = scipy.stats.t.interval(confidence_level, 
                                             degrees_freedom, 
                                             sample_mean, 
                                             sample_standard_error)

# %%
print( 'confidence interval is ', confidence_interval, '.' )
# Out:
# confidence interval is  (34.24453182039489, 34.928367616845144) .

# %%
sample_standard_error # the sample standard error is exactly equal to np.std function which i used!
# Out:
# 0.14694742867989574

# %% [markdown]
# Now construct the 95% confidence interval for all salaried employeed in the police in the cell below.

# %%
police_df
# Out:
#                        Name                              Job Titles  \
# 1         AFFANEH,  MAHIR A                          POLICE OFFICER
# 4           AGEE,  LAWRENCE                          POLICE OFFICER
# 6         AGNEW,  MELISSA M                                SERGEANT
# 7         AGOSTA,  JOSEPH J  POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 9         AGOSTINI,  LUIS R                                ASST DIR
# ...                     ...                                     ...
# 33696  ZYLINSKA,  KATARZYNA                          POLICE OFFICER
# 33697    ZYLINSKA,  KLAUDIA                          POLICE OFFICER
# 33698    ZYMANTAS,  LAURA C                          POLICE OFFICER
# 33699     ZYMANTAS,  MARK E                          POLICE OFFICER
# 33700   ZYRKOWSKI,  CARLO E                          POLICE OFFICER
#
#       Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 1         POLICE                 F           Salary            NaN
# ...

# %%
# Your code here:
plh_df= police_df[police_df["Salary or Hourly"] =='Salary']
pl_sample = plh_df['Annual Salary']
pl_sample
# Out:
# 1         93354.0
# 4         90024.0
# 6        111444.0
# 7        103932.0
# 9         95736.0
#            ...
# 33696     80016.0
# 33697     72510.0
# 33698     76266.0
# 33699     90024.0
# 33700     93354.0
# Name: Annual Salary, Length: 13824, dtype: float64

# %%
len(pl_sample)
# Out:
# 13824

# %%
sum(pl_sample)/2
# Out:
# 614021430.0

# %%
import scipy.stats
from scipy.stats import ttest_1samp

stat3, pval3 = ttest_1samp(pl_sample,13824)

# %%
print('stat is  ', stat3)
print('pvalue for the two-tailed test is ', pval3)
# Out:
# stat is   490.0989817107081
# pvalue for the two-tailed test is  0.0

# %% [markdown]
# # Bonus Challenge - Hypothesis Tests of Proportions
#
# Another type of one sample test is a hypothesis test of proportions. In this test, we examine whether the proportion of a group in our sample is significantly different than a fraction.
#
# You can read more about one sample proportion tests [here](http://sphweb.bumc.bu.edu/otlt/MPH-Modules/BS/SAS/SAS6-CategoricalData/SAS6-CategoricalData2.html).
#
# In the cell below, use the `proportions_ztest` function from `statsmodels` to perform a hypothesis test that will determine whether the number of hourly workers in the City of Chicago is significantly different from 25% at the 95% confidence level.

# %%
# Your code here:
